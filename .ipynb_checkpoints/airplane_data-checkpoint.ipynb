# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/air-passengers-carried.csv')

# %%
df.shape
# Out:
# (8189, 4)

# %%
df.sample(10)
# Out:
#                             Entity Code  Year  \
# 7041                        Sweden  SWE  2002
# 7502                  Turkmenistan  TKM  2001
# 1798  Democratic Republic of Congo  COD  1981
# 2581                       Georgia  GEO  2019
# 4140                    Low income  NaN  1984
# 6978                      Suriname  SUR  1990
# 4713                        Mexico  MEX  1983
# 7606          United Arab Emirates  ARE  1981
# 388                     Azerbaijan  AZE  1994
# 3351                        Israel  ISR  1983
#
#       Air transport, passengers carried
# 7041                         12421220.0
# 7502                          1407423.0
# 1798                           492600.0
# 2581                           509913.0
# 4140                          4383100.0
# 6978                           132500.0
# 4713                         13923500.0
# 7606                           577800.0
# 388                           1380000.0
# 3351                          1578700.0

# %%
df.isna().sum()
# Out:
# Entity                                 0
# Code                                 669
# Year                                   0
# Air transport, passengers carried      0
# dtype: int64

# %%
df[df['Code'].isna()].sample(15)
# Out:
#                             Entity Code  Year  \
# 5451                 North America  NaN  1994
# 5453                 North America  NaN  1996
# 4774  Middle East and North Africa  NaN  1993
# 4820                 Middle income  NaN  1992
# 3843   Latin America and Caribbean  NaN  1990
# 6686                    South Asia  NaN  1998
# 1949         East Asia and Pacific  NaN  2009
# 4778  Middle East and North Africa  NaN  1997
# 4219           Lower middle income  NaN  2020
# 4101         Low and middle income  NaN  1996
# 3864   Latin America and Caribbean  NaN  2011
# 6909            Sub-Saharan Africa  NaN  2017
# 5470                 North America  NaN  2013
# 4113         Low and middle income  NaN  2008
# 4173           Lower middle income  NaN  1974
#
#       Air transport, passengers carried
# 5451                        533028800.0
# 5453                        593928000.0
# 4774                         42087100.0
# 4820                        255049792.0
# 3843                         65165400.0
# 6686                         25389700.0
# 1949                        555699712.0
# 4778                         53725800.0
# 4219                        203386176.0
# 4101                        277787104.0
# 3864                        198178800.0
# 6909                         54260832.0
# 5470                        814697728.0
# 4113                        609013376.0
# 4173                         18433100.0

# %%
income_category = df[
    (df['Entity'] == 'Upper middle income') |
    (df['Entity'] == 'Lower middle income') |
    (df['Entity'] == 'Low and middle income') |
    (df['Entity'] == 'Up and middle income') |
    (df['Entity'] == 'Middle income') |
    (df['Entity'] == 'Low income') |
    (df['Entity'] == 'High income')
]

# %%
income_category
# Out:
#                    Entity Code  Year  Air transport, passengers carried
# 2887          High income  NaN  1970                       2.719993e+08
# 2888          High income  NaN  1971                       2.915812e+08
# 2889          High income  NaN  1972                       3.212242e+08
# 2890          High income  NaN  1973                       3.504047e+08
# 2891          High income  NaN  1974                       3.630511e+08
# ...                   ...  ...   ...                                ...
# 7786  Upper middle income  NaN  2016                       1.068089e+09
# 7787  Upper middle income  NaN  2017                       1.179085e+09
# 7788  Upper middle income  NaN  2018                       1.288616e+09
# 7789  Upper middle income  NaN  2019                       1.361395e+09
# 7790  Upper middle income  NaN  2020                       7.001100e+08
#
# [286 rows x 4 columns]
