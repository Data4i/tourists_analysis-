# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/air-passengers-carried.csv', parse_dates = ['Year'])

# %%
print(f'Shape of the data: {df.shape}')
# Out:
# Shape of the data: (8189, 4)

# %%
df.sample(10)
# Out:
#                      Entity Code       Year  Air transport, passengers carried
# 3216                   Iran  IRN 1985-01-01                          3422000.0
# 7320                  Tonga  TON 1984-01-01                             7800.0
# 5794               Paraguay  PRY 1995-01-01                           105200.0
# 5614                   Oman  OMN 2014-01-01                          5051804.0
# 1039                Burundi  BDI 1978-01-01                             5000.0
# 6124                 Russia  RUS 1993-01-01                         36124000.0
# 1940  East Asia and Pacific  NaN 2000-01-01                        337766624.0
# 5415                Nigeria  NGA 2009-01-01                          1365343.0
# 3498                  Japan  JPN 1979-01-01                         45367800.0
# 3215                   Iran  IRN 1984-01-01                          4087800.0

# %%
df.isna().sum()
# Out:
# Entity                                 0
# Code                                 669
# Year                                   0
# Air transport, passengers carried      0
# dtype: int64

# %%
df[df['Code'].isna()].sample(15)
# Out:
#                            Entity Code       Year  \
# 4815                Middle income  NaN 1987-01-01
# 2312               European Union  NaN 1983-01-01
# 3852  Latin America and Caribbean  NaN 1999-01-01
# 2321               European Union  NaN 1992-01-01
# 4141                   Low income  NaN 1985-01-01
# 6894           Sub-Saharan Africa  NaN 2002-01-01
# 1947        East Asia and Pacific  NaN 2007-01-01
# 6665                   South Asia  NaN 1977-01-01
# 7774          Upper middle income  NaN 2004-01-01
# 4803                Middle income  NaN 1975-01-01
# 7769          Upper middle income  NaN 1999-01-01
# 3867  Latin America and Caribbean  NaN 2014-01-01
# 4162                   Low income  NaN 2014-01-01
# 3830  Latin America and Caribbean  NaN 1977-01-01
# 6694                   South Asia  NaN 2006-01-01
#
#       Air transport, passengers carried
# 4815                        145320000.0
# 2312                        101810304.0
# 3852                         93629696.0
# 2321                        164292000.0
# 4141                          3995300.0
# 6894                         16535011.0
# 1947                        523755808.0
# 6665                          8481700.0
# 7774                        307302144.0
# 4803                         61581100.0
# 7769                        208565408.0
# 3867                        248819232.0
# 4162                         14719339.0
# 3830                         37141200.0
# 6694                         51488172.0

# %%
df = df.sort_values(by = 'Year')

# %%
income_category = df[
    (df['Entity'] == 'Upper middle income') |
    (df['Entity'] == 'Lower middle income') |
    (df['Entity'] == 'Low and middle income') |
    (df['Entity'] == 'Up and middle income') |
    (df['Entity'] == 'Middle income') |
    (df['Entity'] == 'Low income') |
    (df['Entity'] == 'High income')
]

# %%
income_category
# Out:
#                      Entity Code       Year  Air transport, passengers carried
# 4126             Low income  NaN 1970-01-01                          1820500.0
# 2887            High income  NaN 1970-01-01                        271999296.0
# 4169    Lower middle income  NaN 1970-01-01                         14146800.0
# 4170    Lower middle income  NaN 1971-01-01                         13828400.0
# 2888            High income  NaN 1971-01-01                        291581216.0
# ...                     ...  ...        ...                                ...
# 4219    Lower middle income  NaN 2020-01-01                        203386176.0
# 4125  Low and middle income  NaN 2020-01-01                        911243392.0
# 4848          Middle income  NaN 2020-01-01                        903496192.0
# 4168             Low income  NaN 2020-01-01                          7747177.5
# 7790    Upper middle income  NaN 2020-01-01                        700110016.0
#
# [286 rows x 4 columns]

# %%
income_category = income_category.reset_index(drop = True)

# %%
income_category.shape
# Out:
# (286, 4)

# %%
income_category['Entity'].value_counts()
# Out:
# Entity
# High income              51
# Lower middle income      51
# Middle income            47
# Upper middle income      47
# Low and middle income    47
# Low income               43
# Name: count, dtype: int64

# %%
income_category.drop('Code', axis =1, inplace = True)

# %%
income_category['Year'] = income_category['Year'].dt.year

# %%
income_category.sample(3)
# Out:
#                     Entity  Year  Air transport, passengers carried
# 42   Low and middle income  1979                         98846704.0
# 35     Upper middle income  1977                         47474300.0
# 172             Low income  2000                          4776260.0

# %%
high_income = income_category[income_category['Entity'] == 'High income']
middle_income = income_category[income_category['Entity'] == 'Middle income']
low_income = income_category[income_category['Entity'] == 'Low income']
upper_middle_income = income_category[income_category['Entity'] == 'Upper middle income']
lower_middle_income = income_category[income_category['Entity'] == 'Lower middle income']
low_and_middle_income = income_category[income_category['Entity'] == 'Low and middle income']

# %%
def plot_no_of_tourists_against_year(data, title:str):
    plt.figure(figsize = (25,10))
    sns.barplot(data = data, x = 'Year', y = 'Air transport, passengers carried')
    plt.title(f'No of Persenger visiting {str} countries from 1970-2020')
    plt.show()

# %%
plot_no_of_tourists_against_year(high_income, 'High Income')

# %%
plot_no_of_tourists_against_year(middle_income, 'Middle Income')

# %%
plot_no_of_tourists_against_year(upper_middle_income, 'Upper Middle Income')

# %%
plot_no_of_tourists_against_year(lower_middle_income, 'Lower Middle Income')

# %%
plot_no_of_tourists_against_year(low_and_middle_income, 'Low and Middle Income')

# %%
plot_no_of_tourists_against_year(low_income, 'Low Income')

# %%
income_category.groupby('Entity').agg({'mean'})['Air transport, passengers carried'].plot(kind = 'bar', title = 'Mean No of Tourists for each income Group')
plt.show()
